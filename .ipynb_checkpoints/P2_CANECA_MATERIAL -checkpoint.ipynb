# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import pandas

# %%
#Variaveis estaticas
#RECIPIENTE DE CERAMICA

#Temperaturas do ambiente, cafe e do recipiente, respectivamente, em K
Ta = 25.6 + 273.15
Tc = 75.20 + 273.15
Tr = 67.3 + 273.15

#Dimensões da caneca, r (raio interno), R(raio externo), rc(raio intermediario) e h(altura) em metros:
r = 0.04 - 0.003
R = 0.04
rc = (r + R) / 2
h = 0.09

#Massa do cafe e do recipiente em kg, respectivamente:
mc = (math.pi * (r ** 2) * (0.047)) * 1000
mr = ((math.pi * (R ** 2) * h) - (math.pi * (r ** 2) * (h-0.01))) * 2480

#Calores especificos do cafe e do recipiente, em J/(kg*K)
cc = 4186
cr = 1070

#Condutividade termica da ceramica em W/m⋅𝐾
K = 1.5

#coeficiente de convecção do ar em 𝑊/(𝑚^2⋅𝐾)
hs = 42

# %%
def modelo(l, t):
    Tc = l[0]
    Tr = l[1]
    Ti = Tc
    
    qs = (Tc - Ta) / (1 / (hs * math.pi * r ** 2))
    qr = (Tc - Tr) / ((math.log(rc / r))/ (K * 2 * math.pi * h))
    qf = (Ti - Ta) / ((math.log(R/rc) / (K * 2 * math.pi * h)) + (1 / (hs * 2 * math.pi * R * h)))
    dTcdt = (-1 / (mc * cc)) * (qs + qr)
    dTrdt = (1 / (mr * cr)) * (qr - qf)
    return [dTcdt, dTrdt]

# %%
lista_tempo = np.arange(0, 1500, 2)
ci = [Tc, Tr]

x = odeint(modelo, ci, lista_tempo)
tCafe = x[:,0] - 273.15
tRecipiente = x[:,1] - 273.15

plt.plot(lista_tempo/3600, tCafe, label='Temperatura do Café')
plt.plot(lista_tempo/3600, tRecipiente, label='Temperatura do recipiente')
plt.legend()
plt.xlabel("Tempo (horas)")
plt.ylabel("Temperatura do Cafe (C)")
plt.grid(True)
plt.show()

# %%
def modelo2(l, t, K, material):
    cr = dic_ce[material]
    mr = ((math.pi * R ** 2 * h) - (math.pi * r ** 2 * (h-0.01))) * dic_densidade[material]
    
    Tc = l[0]
    Tr = l[1]
    Ti = Tr
    
    qs = (Tc - Ta) / (1 / (hs * math.pi * r ** 2))
    qr = (Tc - Tr) / ((math.log(rc / r))/ (K * 2 * math.pi * h))
    qf = (Ti - Ta) / ((math.log(R/rc) / (K * 2 * math.pi * h)) + (1 / (hs * 2 * math.pi * R * h)))
    dTcdt = (-1 / (mc * cc)) * (qs + qr)
    dTrdt = (1 / (mr * cr)) * (qr - qf)
    return [dTcdt, dTrdt]

# %%
# Condutitivade termica dos materiais W/(m*K)
dic_material = {}
#https://www.sciencedirect.com/topics/engineering/thermal-conductivity-coefficient
#http://hyperphysics.phy-astr.gsu.edu/hbase/Tables/thrcn.html ==> lista mais usada
#https://www.engineeringtoolbox.com/thermal-conductivity-d_429.html
#https://www.engineersedge.com/heat_transfer/thermal_properties_of_nonmetals_13967.htm
dic_material['acrílico'] = 0.187
dic_material['polietileno Alta densidade'] = 0.45
dic_material['polipropileno'] = 0.17
dic_material['vidro'] = 1.05
dic_material['porcelana'] = 1.5
dic_material['Aço inoxidável, tipo 304'] = 14.4
dic_material['ferro'] = 80.0
dic_material['aluminio'] = 205.0
dic_material['poliestireno'] = 0.03

# Densidades dos materiais Kg/(m^3)
dic_densidade = {}
dic_densidade['acrílico'] = 1190
dic_densidade['polietileno Alta densidade'] = 950
dic_densidade['polipropileno'] = 900
dic_densidade['vidro'] = 2500
dic_densidade['porcelana'] = 2480
dic_densidade['Aço inoxidável, tipo 304'] = 800
dic_densidade['ferro'] = 7860
dic_densidade['aluminio'] = 2700
dic_densidade['poliestireno'] = 10

#Calores específicos J/(Kg*K)

dic_ce = {}
dic_ce['acrílico'] = 1460
dic_ce['polietileno Alta densidade'] = 1550
dic_ce['polipropileno'] = 1920
dic_ce['vidro'] = 840
dic_ce['porcelana'] = 1070
dic_ce['Aço inoxidável, tipo 304'] = 500
dic_ce['ferro'] = 460
dic_ce['aluminio'] = 870
dic_ce['poliestireno'] = 1400

for material, i in dic_material.items():
    x = odeint(modelo2, ci, lista_tempo, args=(i, material))
    tcafe = x[:,0]
    plt.plot(lista_tempo , tcafe - 273.15, label = material)

plt.title('Temperatura do café em canecas de diferentes materiais')
plt.legend()
plt.xlabel("Tempo (segundos)")
plt.ylabel("Temperatura do Cafe (C)")
plt.grid(True)
plt.show()

# %%
def conclusivo(lo, lt):
    temp = 60 + 273.15
    
    lista_tcafe = list(lo)
    lista_tempo = list(lt)
    index = int()
    
    for i in lista_tcafe:
        if i <= temp:
            index = lista_tcafe.index(i)
            break
    return lista_tempo[index]

# %%
for material, i in dic_material.items():
        x = odeint(modelo2, ci, lista_tempo, args=(i, material))
        tcafe = x[:,0]
        tempo60 = conclusivo(tcafe,lista_tempo)
        plt.plot(math.log(i), tempo60,'o', label = material)
plt.title('Tempo para chegar e 60°C pela condutividade térmica do material ')
plt.legend()
plt.xlabel("Condutividade térmica do material(log(W/(m^2⋅c)))")
plt.ylabel("Tempo até chegar a 60 graus(segundos)")
plt.grid(True)
plt.show()
